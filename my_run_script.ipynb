# %%
# !tf_upgrade_v2 \
#   --infile pcp.py \
#   --outfile pcp2.py
# Out:
# 2023-11-10 02:16:57.668337: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# INFO line 10:0: Not upgrading symbols because `tensorflow.compat.v1` was directly imported as `tf`.
# INFO line 11:0: Renamed 'tf.disable_v2_behavior' to 'tf.compat.v1.disable_v2_behavior'
# INFO line 112:7: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 121:29: tf.constant_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 121:29: Renamed 'tf.constant_initializer' to 'tf.compat.v1.constant_initializer'
# INFO line 143:7: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 146:14: Added keywords to args of function 'tf.nn.max_pool'
# INFO line 146:14: Renamed keyword argument for tf.nn.max_pool from value to input
# INFO line 146:14: Renamed 'tf.nn.max_pool' to 'tf.nn.max_pool2d'
# WARNING line 163:10: tf.get_variable requires manual check. tf.get_variable returns ResourceVariables by default in 2.0, which have well-defined semantics and are stricter about shapes. You can disable this behavior by passing use_resource=False, or by calling tf.compat.v1.disable_resource_variables().
# INFO line 163:10: Renamed 'tf.get_variable' to 'tf.compat.v1.get_variable'
# INFO line 184:18: Changing tf.contrib.layers xavier initializer to a tf.compat.v1.keras.initializers.VarianceScaling and converting arguments.
#
# INFO line 186:18: tf.truncated_normal_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 186:18: Renamed 'tf.truncated_normal_initializer' to 'tf.compat.v1.truncated_normal_initializer'
# INFO line 190:4: Renamed 'tf.add_to_collection' to 'tf.compat.v1.add_to_collection'
# INFO line 226:7: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 237:16: Added keywords to args of function 'tf.nn.conv2d'
# INFO line 237:16: Renamed keyword argument for tf.nn.conv2d from filter to filters
# INFO line 241:32: tf.constant_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 241:32: Renamed 'tf.constant_initializer' to 'tf.compat.v1.constant_initializer'
# INFO line 331:17: Added keywords to args of function 'tf.reduce_sum'
# INFO line 518:16: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 519:18: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 520:12: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 521:20: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 522:19: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 523:12: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 526:9: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 526:42: Renamed 'tf.AUTO_REUSE' to 'tf.compat.v1.AUTO_REUSE'
# INFO line 527:31: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 528:25: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 531:13: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 531:48: Renamed 'tf.AUTO_REUSE' to 'tf.compat.v1.AUTO_REUSE'
# INFO line 533:21: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 534:34: tf.constant_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 534:34: Renamed 'tf.constant_initializer' to 'tf.compat.v1.constant_initializer'
# INFO line 535:36: tf.random_normal_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 535:36: Renamed 'tf.random_normal_initializer' to 'tf.compat.v1.random_normal_initializer'
# INFO line 536:26: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 538:22: tf.constant_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 538:22: Renamed 'tf.constant_initializer' to 'tf.compat.v1.constant_initializer'
# INFO line 539:24: tf.random_normal_initializer requires manual check. Initializers no longer have the dtype argument in the constructor or partition_info argument in the __call__ method.
# The calls have been converted to compat.v1 for safety (even though they may already have been correct).
# INFO line 539:24: Renamed 'tf.random_normal_initializer' to 'tf.compat.v1.random_normal_initializer'
# INFO line 541:14: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 553:25: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 554:23: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 555:17: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 568:9: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 568:43: Renamed 'tf.AUTO_REUSE' to 'tf.compat.v1.AUTO_REUSE'
# INFO line 569:31: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 570:27: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 574:20: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 576:25: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 577:19: Renamed 'tf.layers.dense' to 'tf.compat.v1.layers.dense'
# INFO line 583:9: Added keywords to args of function 'tf.reduce_mean'
# INFO line 583:24: Added keywords to args of function 'tf.norm'
# INFO line 588:5: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 588:41: Renamed 'tf.AUTO_REUSE' to 'tf.compat.v1.AUTO_REUSE'
# INFO line 603:7: Added keywords to args of function 'tf.reduce_mean'
# INFO line 603:22: Added keywords to args of function 'tf.norm'
# INFO line 605:9: Renamed 'tf.trainable_variables' to 'tf.compat.v1.trainable_variables'
# INFO line 606:8: Renamed 'tf.train.AdamOptimizer' to 'tf.compat.v1.train.AdamOptimizer'
# INFO line 610:14: Renamed 'tf.get_collection' to 'tf.compat.v1.get_collection'
# INFO line 610:32: Renamed 'tf.GraphKeys' to 'tf.compat.v1.GraphKeys'
# INFO line 616:9: Renamed 'tf.ConfigProto' to 'tf.compat.v1.ConfigProto'
# INFO line 617:16: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# INFO line 618:8: Renamed 'tf.train.Saver' to 'tf.compat.v1.train.Saver'
# INFO line 623:5: Renamed 'tf.Session' to 'tf.compat.v1.Session'
# INFO line 637:17: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# WARNING line 659:16: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# WARNING line 661:8: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# INFO line 670:21: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# WARNING line 696:20: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# INFO line 723:17: Renamed 'tf.global_variables_initializer' to 'tf.compat.v1.global_variables_initializer'
# TensorFlow 2.0 Upgrade Script
# -----------------------------
# Converted 1 files
# Detected 4 issues that require attention
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# File: pcp.py
# --------------------------------------------------------------------------------
# pcp.py:163:10: WARNING: tf.get_variable requires manual check. tf.get_variable returns ResourceVariables by default in 2.0, which have well-defined semantics and are stricter about shapes. You can disable this behavior by passing use_resource=False, or by calling tf.compat.v1.disable_resource_variables().
# pcp.py:659:16: WARNING: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# pcp.py:661:8: WARNING: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
# pcp.py:696:20: WARNING: *.save requires manual check. (This warning is only applicable if the code saves a tf.Keras model) Keras model.save now saves to the Tensorflow SavedModel format by default, instead of HDF5. To continue saving to HDF5, add the argument save_format='h5' to the save() function.
#
#
# Make sure to read the detailed log 'report.txt'

# %%
import os
import datetime
# 读取一个文件夹下的所有文件
base_dir = './data'
dataset = 'taught'
floder = base_dir + '/' + dataset + '/'
files = os.listdir(floder)
# 过滤后缀不是ply的文件
files = [file for file in files if file.endswith('.ply')]
print(files)

for i in range(len(files)):
    # 记录时间
    starti = str(datetime.datetime.now())
    f = files[i]
    # 设置输出路径
    output_local_dir = './local_net/'+dataset+'/'+f.split('.')[0]+'/'
    output_global_dir = './glocal_net/'+dataset + '/'+f.split('.')[0]+'/'
    
    # 打印进度和当前文件名
    print('processing: ' + f + ' ' + str(i) + '/' + str(len(files)))
    base_cmd = 'python pcp2.py ' + '--CUDA 0 --save_idx -1' + ' --data_dir ' + floder + ' --OUTPUT_DIR_LOCAL ' + output_local_dir + ' --OUTPUT_DIR_GLOBAL ' + output_global_dir + ' --input_ply_file ' + f
    # 设置log文件路径
    log_file = './log/' + dataset + '/' + f.split('.')[0] + '.log'
    # 创建log文件夹
    if not os.path.exists('./log/'):
        os.mkdir('./log/')
    if not os.path.exists('./log/' + dataset):
        os.mkdir('./log/' + dataset)    

    train_local_cmd = base_cmd  + ' --train   '
    train_pred_cmd  = base_cmd  + ' --finetune'
    test_cmd        = base_cmd  + ' --test    '
    
    cmds = [train_local_cmd, train_pred_cmd, test_cmd]
    # 设置命令
    print('-----------------------------------')
    for cmd in cmds:
        # cmd = cmd + ' --log_file ' + log_file
        print(cmd)
        startcmdi = datetime.datetime.now()
        with open(log_file, 'a') as f:
            f.write('-----------------------------------\n')
            f.write(cmd + '\n')
            f.write("start: " + str(startcmdi) + '\n')
        os.system(cmd)   
        with open(log_file, 'a') as f:
            f.write("end:   " + str(datetime.datetime.now()) + '\n\n')
            f.write('cost:  ' + str(datetime.datetime.now() - startcmdi) + '\n')
    
    # 记录时间
    endi = str(datetime.datetime.now())
    # 写入时间
    with open(log_file, 'a') as f:
        f.write('start: ' + starti + '\n')
        f.write('end:   ' + endi + '\n')
        f.write('-----------------------------------\n')
    print('-----------------------------------\n')
# Out:
# ['scene0001_00_vh_clean_2.ply', 'scene0017_00_vh_clean_2.ply', 'scene0018_00_vh_clean_2.ply', 'scene0022_00_vh_clean_2.ply', 'scene0059_00_vh_clean_2.ply', 'scene0068_00_vh_clean_2.ply', 'trash_can2.ply', 'Zshape.ply']
# processing: scene0001_00_vh_clean_2.ply 0/8
# -----------------------------------
# python pcp2.py --CUDA 0 --save_idx -1 --data_dir ./data/taught/ --OUTPUT_DIR_LOCAL ./local_net/taught/scene0001_00_vh_clean_2/ --OUTPUT_DIR_GLOBAL ./glocal_net/taught/scene0001_00_vh_clean_2/ --input_ply_file scene0001_00_vh_clean_2.ply --train
# python pcp2.py --CUDA 0 --save_idx -1 --data_dir ./data/taught/ --OUTPUT_DIR_LOCAL ./local_net/taught/scene0001_00_vh_clean_2/ --OUTPUT_DIR_GLOBAL ./glocal_net/taught/scene0001_00_vh_clean_2/ --input_ply_file scene0001_00_vh_clean_2.ply --finetune
